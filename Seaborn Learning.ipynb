# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips =  sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill'] ,  kde = False , bins = 40) #single variable plot
#gives histogram and kde

# %%
#multi variable plot
sns.jointplot(x= , y= , data= )#2 distplots for bivarient data

# %%
sns.jointplot(x='total_bill' , y='tip' , data= tips , kind = 'hex') #pass column names, kind  = style

# %%
sns.jointplot(x='total_bill' , y='tip' , data= tips , kind = 'reg')

# %%
sns.jointplot(x='total_bill' , y='tip' , data= tips , kind = 'kde')

# %%
sns.pairplot(tips)#pairwise relationship accross the dataset for numerical columns
              # takes hue for categorical columns

# %%
sns.pairplot(tips , hue = 'sex' )

# %%
sns.rugplot(tips['total_bill']) #single column

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# ### Categorical plots

# %%
sns.barplot(x='sex' , y='total_bill' , data=tips)

# %%
import numpy as np
sns.barplot(x='sex' , y='tip' , data=tips , estimator = np.std)

# %%
#estimator counts number of occurences
sns.countplot(x='smoker' , data = tips)

# %%
#box and whisker shows distribution
sns.boxplot(x= 'day',y ='total_bill' , data=tips)

# %%
sns.boxplot(x= 'day',y ='total_bill' , data=tips , hue='smoker')

# %%
#violin plot
#shows kde of underlying distribution
sns.violinplot(x='day' , y = 'total_bill' , data = tips)

# %%
sns.violinplot(x='day' , y = 'total_bill' , data = tips , hue = 'smoker', split = True)

# %%
sns.stripplot(x='day' , y='total_bill' , data = tips , hue='sex' , dodge = True)

# %%
sns.violinplot(x='day' , y='total_bill' , data = tips , color='red' )
sns.swarmplot(x='day' , y='total_bill' , data = tips  , hue = 'sex')

# %%
sns.jointplot(x='total_bill' , y='tip' , data= tips)

# %% [markdown]
# ## Matrix Plots
# <ul style = 'color:green'>
# <li>Correlational data: <span style='color:black'>must have named index and column for relevence</span></li>
# <li>Heatmap: <span style='color:black'> use data.corr() or pivot tables, represents data on a color scale <br> sns.heatmap(tc , annot= True , color = 'coolwarm') , annot adds numbers into the graph</span></li>
# <li>Pivot table:  <span style='color:black'>data.pivot_table(index = 'month' , columns ='year' , values = 'passengers')<br>
# cmap='magma', linewidths , linecolor
# </span></li>
# <li>Cluster map: <span style='color:black'>Uses hierarchial clustering , <br>
# sns.clustermap() clusters similar information , good for comparing
# </span></li>
# <!-- <li>Cluster map: <span style='color:black'> adda <br> </span></li>
#
# </ul> -->

# %%
df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
pv1 = df.pivot_table(index = 'carat' , columns = 'clarity' , values = 'price')
fig, ax = plt.subplots(figsize=(10 , 30))
sns.heatmap(ax = ax , data = pv1)

# %%
flights = sns.load_dataset('flights')
pv1 = flights.pivot_table(index = 'year' , columns = 'month' , values = 'passengers')
pv1
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
# 1954       204       188    235    227  234   264   302     293        259
# 1955       242       233    267    269  270   315   364     347        312
# 1956       284       277    317    313  318   374   413     405        355
# 1957       315       301    356    348  355   422   465     467        404
# 1958       340       318    362    348  363   435   491     505        404
# 1959       360       342    406    396  420   472   548     559        463
# ...

# %%
sns.clustermap(pv1 , cmap = 'coolwarm' , linecolor='white' , linewidths = 2)

# %%
sns.heatmap(df.corr() , linewidths = 3)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris) # creates empty grids
g.map(plt.scatter) #plot at diagonal

# %%
h = sns.PairGrid(iris) # creates empty grids
h.map_diag(sns.distplot)
h.map_upper(plt.scatter)
h.map_lower(sns.kdeplot)

# %% [markdown]
# ###  Regression plots

# %%
sns.lmplot(x='total_bill' , y = 'tip' , data = tips , hue = 'smoker' , markers = ['s' , 'v'])

# %%
sns.lmplot(x='total_bill' , y = 'tip' , data = tips , col = 'sex' , hue = 'smoker')

# %%
sns.lmplot(x='total_bill' , y = 'tip' , data = tips , col = 'sex' , hue = 'smoker' , aspect = 0.6 , height = 10)
sns.despine( bottom = True)

# %% [markdown]
# ## Seaborn styling

# %%
plt.figure(figsize=(10,5))
sns.set_style('white')
sns.countplot(x='sex' ,data =tips)

# %%
sns.lmplot(x= 'total_bill', y= 'tip' , data = tips , hue = 'smoker' , palette = 'seismic')

# %% [markdown]
# ###  CLEAN GRAPH

# %%
sns.set_context('notebook' , font_scale = 1.5)
ax = sns.countplot( x='sex' ,data =tips)
ax.set_yticklabels([])
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height-15,
            '{}'.format(height),
            ha='center' , va = 'baseline' , color = 'white') 
sns.despine(left = True , bottom = True)
