# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
import PyPDF2
import tabula

# %% [markdown]
# ### Methods

# %%
def get_files_list(url):
    #Create a handle, page, to handle the contents of the website
    page = requests.get(url)
    #Store the contents of the website under doc
    doc = lh.fromstring(page.content)
    #look for links in the website
    tree = lh.fromstring(page.text)
    links = []
    for link_element in tree.xpath('//td//a')[1:]:
        links.append(link_element.get('href'))
    return links

def save_list(li):
    with open('FilesList.txt', 'w') as filehandle:
        for listitem in li:
            filehandle.write('%s\n' % listitem)
        print('List saved as FilesList.txt')

def load_list(): 
    lines = []
    with open('FilesList.txt', 'r') as filehandle:        
        lines = [line[:-1] for line in filehandle]
    return lines

def download_file(u , f):
   
    url = u + f
    response = requests.get(url)
    file_name = url.split('/')[-1:][0]
    try:
        with open(file_name, 'wb') as f:
            f.write(response.content)
            print(file_name +' saved!')
    except:
        print('failed to download {}\n'.format(file_name))
    
    
def get_new_files(url):
    links = get_files_list(url)
    #check for updates
    old = load_list()
    updates = []
    for item in links :    
        if item not in old:
            updates.append(item)
    #download new files in site
    for item in updates:
        download_file(url , item)
    #save current list
    save_list(links)
    print("new files from website saved")

def get_latest_dl(): #get file name from downloads list
    with open('FilesList.txt', 'r') as filehandle:        
        lines = [line for line in filehandle]
    return lines[0].split()[0]


def pdf_to_csv(file = get_latest_dl()): #input pdf name or by default uses latest file
    df = tabula.read_pdf(file, pages = [1, 2])#does not read first table
    final = df[1]
    final.columns = ['Location' , 'Total']
    for idx , dfa in enumerate(df[2:]):
        x = dfa[:].values
        x = np.append(x, [final.columns[0] , final.columns[1]])
        dataset = pd.DataFrame({final.columns[0]: x[0:-2:2], final.columns[1]: x[1:-2:2]})
        final = pd.concat([final , dataset])

    final = final.reset_index(drop = True)

    final.to_csv('corona.csv' , index = False)
    print('saved as corona.csv')

# %%
url = 'https://www.iedcr.gov.bd/website/images/files/nCoV/'
get_new_files(url)
# Out:
# failed to download %e0%a6%95%e0%a6%bf%e0%a6%9b%e0%a7%81%20%e0%a6%ad%e0%a7%8d%e0%a6%b0%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%20%e0%a6%a7%e0%a6%be%e0%a6%b0%e0%a6%a3%e0%a6%be%20%e0%a6%93%20%e0%a6%a4%e0%a6%be%e0%a6%b0%20%e0%a6%9c%e0%a6%ac%e0%a6%be%e0%a6%ac-4%20(draft).pdf
#
# failed to download %e0%a6%95%e0%a6%bf%e0%a6%9b%e0%a7%81%20%e0%a6%ad%e0%a7%8d%e0%a6%b0%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%20%e0%a6%a7%e0%a6%be%e0%a6%b0%e0%a6%a3%e0%a6%be%20%e0%a6%93%20%e0%a6%a4%e0%a6%be%e0%a6%b0%20%e0%a6%9c%e0%a6%ac%e0%a6%be%e0%a6%ac.pdf
#
# 19_April.jpg saved!
# 24_June_2020.pdf saved!
# 27_June_2020.pdf saved!
# 30.01.2020_Press%20release%20nCoV.pdf saved!
# 30_June_2020.pdf saved!
# 2019-nCoV%20Press%20Release_29012020.pdf saved!
# 2020-01-28%20presentation%20for%20civil%20surgeons.pdf saved!
# 2020-02-05%20Update%20nCoV%20Press%20release.pdf saved!
# 2020-02-08%20nCoV%20Press%20release.pdf saved!
# 2020-02-09%20nCoV%20Press%20release.pdf saved!
# 2020-02-10%20nCoV%20Press%20release.pdf saved!
# 2020-02-11%20nCoV%20Press%20release.pdf saved!
# 2020-02-12%20CoVID%2019%20Press%20release.pdf saved!
# 2020-02-13%20CoVID%2019%20Press%20release.pdf saved!
# 2020-02-14%20CoVID%2019%20Press%20release.pdf saved!
# 2020-02-15%20CoVID%2019%20Press%20release.pdf saved!
# 2020-02-16%20CoVID%20Routine%20Press%20release.pdf saved!
# 2020-02-17%20CoVID%20Press%20release.pdf saved!
# 2020-02-18%20CoVID%20Press%20release.pdf saved!
# 2020-02-19%20CoVID%20Press%20release.pdf saved!
# 2020-02-20%20CoVID%20Press%20release.pdf saved!
# 2020-02-21%20CoVID%20Press%20release.pdf saved!
# 2020-02-22%20CoVID%20Press%20release.pdf saved!
# 2020-02-23%20CoVID%20Press%20release.pdf saved!
# 2020-02-24%20CoVID%20Press%20release.pdf saved!
# 2020-02-25%20CoVID%20Press%20release.pdf saved!
# 2020-02-26%20CoVID%20Press%20release.pdf saved!
# 2020-02-27%20CoVID%20Press%20release.pdf saved!
# 2020-02-28%20CoVID%20Press%20release.pdf saved!
# 2020-02-29%20CoVID%20Press%20release.pdf saved!
# 2020-03-01%20CoVID%20Press%20release.pdf saved!
# 2020-03-02%20CoVID%20Press%20release.pdf saved!
# 2020-03-03%20CoVID%20Press%20release.pdf saved!
# 2020-03-04%20CoVID%20Press%20release.pdf saved!
# 2020-03-05%20CoVID%20Press%20release.pdf saved!
# 2020-03-06%20CoVID%20Press%20release.pdf saved!
# 2020-03-07%20CoVID%20Press%20release.pdf saved!
# 2020-03-08%20CoVID%20Press%20release.pdf saved!
# 2020-03-09%20CoVID%20Press%20release.pdf saved!
# 2020-03-10%20CoVID%20Press%20release.pdf saved!
# 2020-03-11%20CoVID%20Press%20release.pdf saved!
# 2020-03-12%20CoVID%20Press%20release.pdf saved!
# 2020-03-13%20CoVID%20Press%20release.pdf saved!
# 2020-03-14%20CoVID%20Press%20release1.pdf saved!
# 2020-03-15%20CoVID%20Press%20release.pdf saved!
# 2020-03-16%20CoVID%20Press%20release.pdf saved!
# 2020-03-17%20CoVID%20Press%20release.pdf saved!
# 20200120-ncov-home-care-infected-patients%20(1).pdf saved!
# 20200127-sitrep-7-2019--ncov.pdf saved!
# 20200204-sitrep-15-ncov.pdf saved!
# 20200205-sitrep-16-ncov.pdf saved!
# 20200207-sitrep-18-ncov.pdf saved!
# 20200227-sitrep-38-covid-19.pdf saved!
# 20200229-sitrep-40-covid-19.pdf saved!
# Advice-on-the-use-of-masks.pdf saved!
# Advice%20on%20the%20use%20of%20masks_updated_6%20April.pdf saved!
# Case_dist_30_May_upload.pdf saved!
# Clinical%20Management%20of%20COVID-19.pdf saved!
# Disease%20Commodity%20Package_updated%206%20March%202020.pdf saved!
# Disease%20comodity%20package-nCoV.pdf saved!
# Draft%20of%20Home%20care%20for%20patients.pdf saved!
# FAQ_COVID-19.pdf saved!
# FAQ%20for%20website%20upload_v2.pdf saved!
# Global-surveillance-for-2019-ncov.pdf saved!
# Global%20Surveillance%20for%20Human%20Infection_update_20%20March%202020.pdf saved!
# Health%20Card.jpg saved!
# Helth_card_10032020.jpg saved!
# Home%20Care%20for%20COVID%2019%20patients.pdf saved!
# Home%20Care%20of%20COVID-19%20Infected%20Patients.pdf saved!
# Home%20Quarantine%20(draft%20version).pdf saved!
# Home%20quarantine.pdf saved!
# Infection%20Prevention%20and%20Control%20Recommendations_v2.pdf saved!
# Mask%20use_nCoV.pdf saved!
# Press%20Release%20%20on%202019-nCoV%2028012020.pdf saved!
# Press%20release_01022020%20nCoV.pdf saved!
# Press%20release_nCoV%2031%2001%202020.pdf saved!
# Public%20announcement%20for%20COVID-19.pdf saved!
# Rational%20use%20of%20PPE_updated_19%20March%202020.pdf saved!
# Risk%20Communication%20&%20Community%20Management_update_19%20March%202020.pdf saved!
# Surveillance-case-definitions-ncov-final.pdf saved!
# Surveillance%20Case%20Definition_updated%2020%20March%202020.pdf saved!
# Suspected%20COVID-19%20Case%20Report%20and%20Laboratory%20Test%20Request%20Form_updated_04.04.2020.pdf saved!
# Suspected_COVID-19_CRF.pdf saved!
# Travel%20advice%20final.pdf saved!
# WHO-2019-nCoV-IPC-v2020.1-eng.pdf saved!
# WHO-2019-nCoV-RCCE-v2020.1-eng.pdf saved!
# WHO-2019-nCov-IPCPPE_use-2020.1-eng.pdf saved!
# WHO-nCov-IPC_Masks-2020.1-eng.pdf saved!
# clinical-management-of-novel-cov.pdf saved!
# flow%20chart%20for%20all%20arriving%20passengers.pdf saved!
# leaflet%20final%20v4.pdf saved!
# nCoV%20Press%20Release%2002022020.pdf saved!
# nCoV%20Press%20release%2004022020.pdf saved!
# nCoV%20Press%20release_07-02-2020.pdf saved!
# nCoV%20Press%20release_2020-02-03.pdf saved!
# nCoV%20Press%20release_2020-02-06.pdf saved!
# List saved as FilesList.txt
# new files from website saved

# %%
pdf_to_csv()
# Out:
# Got stderr: Jun 13, 2020 11:46:58 AM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# Jun 13, 2020 11:47:00 AM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# Jun 13, 2020 11:47:02 AM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# saved as corona.csv

# %%
# pdf = open(get_latest_dl() ,'rb')
# pdfReader = PyPDF2.PdfFileReader(pdf)
# extracted_text = ""

# # number of pages in pdf
# print(pdfReader.numPages)
# # a page object
# for page in range(1,2):
#     pageObj = pdfReader.getPage(page)
#     # extracting text from page.
#     extracted_text+= pageObj.extractText()
# aux = extracted_text.split()[12:]
# aux
# Out:
# 3
