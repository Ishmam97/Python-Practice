# %%
import pandas as pd

pd.set_option('display.max_rows', 30) #figure out how to display specific no. of rows other than specifying head

df = pd.read_csv('pokemon.csv')
df = df.drop(columns=['#'])

# %%
df = df.sort_index(0)
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
ldf = df.set_index(['Generation' , 'Legendary'])
#ldf = df
ldf.sort_index(0 , ascending = [1 , 0]) #ascending generation descnding legendary False = 0 True = 1
# Out:
#                                      Name    Type 1    Type 2  Total   HP  \
# Generation Legendary
# 1          True                  Articuno       Ice    Flying    580   90
#            True                    Zapdos  Electric    Flying    580   90
#            True                   Moltres      Fire    Flying    580   90
#            True                    Mewtwo   Psychic       NaN    680  106
#            True       MewtwoMega Mewtwo X   Psychic  Fighting    780  106
# ...                                   ...       ...       ...    ...  ...
# 6          False      GourgeistSuper Size     Ghost     Grass    494   85
#            False                 Bergmite       Ice       NaN    304   55
#            False                  Avalugg       Ice       NaN    514   95
#            False                   Noibat    Flying    Dragon    245   40
#            False                  Noivern    Flying    Dragon    535   85
#
# ...

# %%
for index , row in ldf.iterrows():
        if index == True
        print(row['Name'])
# Out:
# Bulbasaur False
# Ivysaur False
# Venusaur False
# VenusaurMega Venusaur False
# Charmander False
# Charmeleon False
# Charizard False
# CharizardMega Charizard X False
# CharizardMega Charizard Y False
# Squirtle False
# Wartortle False
# Blastoise False
# BlastoiseMega Blastoise False
# Caterpie False
# Metapod False
# Butterfree False
# Weedle False
# Kakuna False
# Beedrill False
# BeedrillMega Beedrill False
# Pidgey False
# Pidgeotto False
# Pidgeot False
# PidgeotMega Pidgeot False
# Rattata False
# Raticate False
# Spearow False
# Fearow False
# Ekans False
# Arbok False
# Pikachu False
# Raichu False
# Sandshrew False
# Sandslash False
# Nidoran♀ False
# Nidorina False
# Nidoqueen False
# Nidoran♂ False
# Nidorino False
# Nidoking False
# Clefairy False
# Clefable False
# Vulpix False
# Ninetales False
# Jigglypuff False
# Wigglytuff False
# Zubat False
# Golbat False
# Oddish False
# Gloom False
# Vileplume False
# Paras False
# Parasect False
# Venonat False
# ...
